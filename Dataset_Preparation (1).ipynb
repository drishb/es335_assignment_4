# %% [markdown]
# ### **Dataset Preparation**

# %%
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading bing_image_downloader-1.1.2-py3-none-any.whl.metadata (2.8 kB)
# Downloading bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.1.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from bing_image_downloader import downloader

# Specify the search terms
search_terms = ["panda", "duck"]
num_images = 100

for term in search_terms:
    downloader.download(term, limit=num_images, output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60)

print("Images downloaded successfully!")
# Out:
# [%] Downloading Images to /content/dataset/panda
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/c/cd/Panda_Cub_from_Wolong%2C_Sichuan%2C_China.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/0/0f/Grosser_Panda.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.natgeofe.com/k/75ac774d-e6c7-44fa-b787-d0e20742f797/giant-panda-eating_3x2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://img.freepik.com/photos-premium/bebe-panda-mignon-humoristique-suspendu-du-bambou_410516-25873.jpg?w=2000
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://img.freepik.com/premium-photo/cute-little-baby-panda-bear-giant-panda-cub_691560-1717.jpg?w=1380
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.fodors.com/wp-content/uploads/2018/11/shutterstock_374877793.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://good-nature-blog-uploads.s3.amazonaws.com/uploads/2022/09/4D1227F6-C40E-4E14-9C3D-AD1E88DF60E6.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://upload.wikimedia.org/wikipedia/commons/0/0e/Atlanta_Zoo_Panda.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://blog.education.nationalgeographic.org/wp-content/uploads/2016/09/embarrassment-of-pandas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://upload.wikimedia.org/wikipedia/commons/8/8d/Giant_Panda_Eating.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from http://aliljoy.com/wp-content/uploads/2012/07/Baby-panda-Wolong-Panda-Center-China.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://www.xtrafondos.com/wallpapers/panda-rojo-sobre-arbol-10595.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://www.rollingstone.com/wp-content/uploads/2022/06/panda-dltf.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://wallpapers.com/images/hd/girly-panda-6l0kbc94qh8zl2au.jpg
# [Error]Invalid image, not saving https://wallpapers.com/images/hd/girly-panda-6l0kbc94qh8zl2au.jpg
#
# [!] Issue getting: https://wallpapers.com/images/hd/girly-panda-6l0kbc94qh8zl2au.jpg
# [!] Error:: Invalid image, not saving https://wallpapers.com/images/hd/girly-panda-6l0kbc94qh8zl2au.jpg
#
# [%] Downloading Image #14 from https://as1.ftcdn.net/v2/jpg/05/55/47/58/1000_F_555475895_fsRSDVWKgE4g08yYL5Rn2T5Q0leBmnXc.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from http://3.bp.blogspot.com/-eT9la6thRY8/UFb26wXe8XI/AAAAAAAAAqw/CVJTn489DD0/s1600/Brilliant+Red+Panda.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://media.cnn.com/api/v1/images/stellar/prod/230711232557-02-panda-ai-bao-babies-0711.jpg?c=16x9&amp;q=h_833,w_1480,c_fill
# [%] File Downloaded !
#
# [%] Downloading Image #17 from http://raannt.com/wp-content/uploads/2014/09/panda_raannt-1024x684.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://www.naturesafariindia.com/wp-content/uploads/2022/03/Giant-Panda.jpg
# [!] Issue getting: https://www.naturesafariindia.com/wp-content/uploads/2022/03/Giant-Panda.jpg
# [!] Error:: HTTP Error 520:
# [%] Downloading Image #18 from http://tblefor2.files.wordpress.com/2011/12/panda1.jpg
# [Error]Invalid image, not saving http://tblefor2.files.wordpress.com/2011/12/panda1.jpg
#
# [!] Issue getting: http://tblefor2.files.wordpress.com/2011/12/panda1.jpg
# [!] Error:: Invalid image, not saving http://tblefor2.files.wordpress.com/2011/12/panda1.jpg
#
# [%] Downloading Image #18 from https://wallpapercave.com/wp/wp5850401.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://segredosdomundo.r7.com/wp-content/uploads/2019/08/urso-panda-habitat-natural-reproducao-e-mais-curiosidades.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from http://www.grosser-panda.de/images/panda1.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://d80g3k8vowjyp.cloudfront.net/img/panda_gigante_2_98522.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://www.ourendangeredworld.com/wp-content/uploads/2021/07/Adult-Giant-Panda.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://filmdaily.co/wp-content/uploads/2020/08/cutepanda-lede-1300x869.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://cdn.images.express.co.uk/img/dynamic/109/590x/secondary/PANDA-865718.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://www.wwf.de/fileadmin/_processed_/0/f/csm_grosser-panda-china-WW230176-c-brad-josephs_a0c92201ef.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://assets.wwf.org.uk/img/original/panda_wallpaper_1024x768.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://i.pinimg.com/originals/7d/92/c7/7d92c7ac446b32940789c29df33c9cab.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from http://upload.wikimedia.org/wikipedia/commons/c/c6/Red_Panda.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://i.pinimg.com/originals/27/cf/9b/27cf9b385c2354a056823b2c9f67f1b8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://einfachtierisch.de/media/cache/article_teaser/cms/2013/02/Panda-Baeren-Babys-Spielen-Wiese.jpg?595617
# [%] File Downloaded !
#
# [%] Downloading Image #31 from http://www.hdwallpapersfreedownload.com/uploads/large/animals/panda-normal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://ichef.bbci.co.uk/news/976/cpsprodpb/92D3/production/_97978573_151104.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #33 from https://wallpapercave.com/wp/wp3975033.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://i.natgeofe.com/k/75ac774d-e6c7-44fa-b787-d0e20742f797/giant-panda-eating.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://i.natgeofe.com/k/6a96c3b4-2be1-498f-972e-76a20d973376/3_Baby_Pandas_KIDS_0322_16x9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #36 from https://financialtribune.com/sites/default/files/field/image/17january/13_panda_267.jpg
# [!] Issue getting: https://financialtribune.com/sites/default/files/field/image/17january/13_panda_267.jpg
# [!] Error:: <urlopen error timed out>
# [%] Downloading Image #36 from https://api.time.com/wp-content/uploads/2015/02/panda-cub.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://images2.alphacoders.com/646/thumb-1920-646040.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://files.worldwildlife.org/wwfcmsprod/images/Panda_in_Tree/story_full_width/8u3k0zn66i_Large_WW170579.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://www.georgetown.edu/wp-content/uploads/2023/11/DSC_7947-2000x1125.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://www.kickassfacts.com/wp-content/uploads/2016/11/panda-bear.jpg
# [!] Issue getting: https://www.kickassfacts.com/wp-content/uploads/2016/11/panda-bear.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #40 from https://i2.wp.com/cdn.history.com/sites/2/2017/03/GettyImages-157278376.jpg
# [!] Issue getting: https://i2.wp.com/cdn.history.com/sites/2/2017/03/GettyImages-157278376.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #40 from https://s1.it.atcdn.net/wp-content/uploads/2014/09/HERO-Kai-Kai-Jia-Jia2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://cdn.i-scmp.com/sites/default/files/d8/images/canvas/2023/05/29/5d5a593d-d9b2-4cb6-86ba-349342a8364f_44459f1b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from http://www.onthegotours.com/repository/Giant-Panda-sitting-on-forest-ground--China-Tours--On-The-Go-Tours-279771450457645_crop_800_600.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from http://static.independent.co.uk/s3fs-public/thumbnails/image/2015/10/08/15/Hong-Kong-pandas.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from http://www.fotosucht.ch/data/media/209/Panda.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://wallpapers-all.com/uploads/posts/2016-12/19_panda.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://www.allkpop.com/upload/2023/05/content/021612/web_data/allkpop_1683058916_untitled-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://cdn.britannica.com/72/100372-050-9CA0D326/Giant-panda-animal-mammal.jpg
# [Error]Invalid image, not saving https://cdn.britannica.com/72/100372-050-9CA0D326/Giant-panda-animal-mammal.jpg
#
# [!] Issue getting: https://cdn.britannica.com/72/100372-050-9CA0D326/Giant-panda-animal-mammal.jpg
# [!] Error:: Invalid image, not saving https://cdn.britannica.com/72/100372-050-9CA0D326/Giant-panda-animal-mammal.jpg
#
# [%] Downloading Image #47 from http://upload.wikimedia.org/wikipedia/commons/2/25/Lesser_panda_standing.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #48 from http://upload.wikimedia.org/wikipedia/commons/f/f1/Red_panda_eating_bamboo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://2.bp.blogspot.com/-4nUURFSnIZI/WLta_dq7R8I/AAAAAAAAAjQ/F-ByUT_7ScUpIU57mLK9XjVBo4qhdvCNgCLcB/s1600/989234.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://worldanimalnews.com/wp-content/uploads/2023/02/7C8285D9-6D6E-43EA-8625-22F165A3E127.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #51 from https://img-s-msn-com.akamaized.net/tenant/amp/entityid/AA1tTHts.img?w=2121&amp;h=1414&amp;m=4&amp;q=89
# [%] File Downloaded !
#
# [%] Downloading Image #52 from https://darlingquote.com/wp-content/uploads/2023/01/1-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://cdn.pixabay.com/photo/2016/02/16/10/46/panda-1203104_960_720.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from https://www-bibliadabiblia-com-br.dnsimg.com/bimg/2024/11/3efea683fefac09ad8541fb190829458-16.png
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://cdn.pixabay.com/photo/2019/09/08/19/54/panda-4461766_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://thumbs.dreamstime.com/z/panda-bears-cubs-playing-sichuan-china-one-bifengxia-base-reserve-51504021.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #57 from https://cdn.pixabay.com/photo/2022/02/15/19/39/panda-7015575_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #58 from https://a-z-animals.com/media/animals/images/original/giant_panda4.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #59 from https://wallpaper-house.com/data/out/10/wallpaper2you_399848.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #60 from http://wasteawarebusiness.files.wordpress.com/2011/01/giant-panda-cub-china4.jpg
# [Error]Invalid image, not saving http://wasteawarebusiness.files.wordpress.com/2011/01/giant-panda-cub-china4.jpg
#
# [!] Issue getting: http://wasteawarebusiness.files.wordpress.com/2011/01/giant-panda-cub-china4.jpg
# [!] Error:: Invalid image, not saving http://wasteawarebusiness.files.wordpress.com/2011/01/giant-panda-cub-china4.jpg
#
# [%] Downloading Image #60 from http://i1.wp.com/www.kickassfacts.com/wp-content/uploads/2016/11/panda-bear.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #61 from https://upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Grosser_Panda.JPG/640px-Grosser_Panda.JPG
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Grosser_Panda.JPG/640px-Grosser_Panda.JPG
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Grosser_Panda.JPG/640px-Grosser_Panda.JPG
# [!] Error:: Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Grosser_Panda.JPG/640px-Grosser_Panda.JPG
#
# [%] Downloading Image #61 from https://png.pngtree.com/png-clipart/20220909/original/pngtree-baby-panda-cartoon-png-image_8503952.png
# [%] File Downloaded !
#
# [%] Downloading Image #62 from https://cdn.pixabay.com/photo/2023/08/05/15/42/panda-8171354_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from https://free-images.com/sm/da31/panda_giant_panda_bear_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #64 from https://i.pinimg.com/originals/7f/04/79/7f04791f964dabb57fcb2e07a55ec34b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #65 from https://a-z-animals.com/media/2022/08/iStock-914100676.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #66 from https://art.hudistore.com/wp-content/uploads/2024/11/Leonardo_Phoenix_This_white_black_pandashaped_sofa_appears_to_2-jpg.webp
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
# [%] Downloading Image #67 from https://static.businessinsider.com/image/51dd6b0ceab8eaa223000013/image.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from https://gdb.voanews.com/3ED6FCAB-D280-4197-8B02-BCCD9846076A_w1200_r1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from http://media.npr.org/assets/news/2010/04/11/panda-f8a7c9331bbac776e52b26feeccc53de959f46d1-s6-c30.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #70 from http://upload.wikimedia.org/wikipedia/commons/c/c8/Waving_Panda.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #71 from http://static.artfcity.com/wp-content/uploads/2013/10/Cute-Panda-Bears-animals-34916401-1455-1114.jpg
# [!] Issue getting: http://static.artfcity.com/wp-content/uploads/2013/10/Cute-Panda-Bears-animals-34916401-1455-1114.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #71 from https://i.pinimg.com/originals/7a/7b/ab/7a7bab94251a5afd39ea35b3611a2e2e.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #72 from http://3.bp.blogspot.com/-o9xfn0a_xJ8/Ub6_InF-sgI/AAAAAAAAHUw/qrR0a5PlCw8/s1600/Panda-Lovely-Wild-Animal.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://animals.sandiegozoo.org/sites/default/files/2016-09/animals_hero_panda.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://i.natgeofe.com/k/6f2282df-1c6a-474a-9216-ed97b3dce858/Panda-Bamboo_Panda-Quiz_KIDS_1021.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #75 from https://nationalzoo.si.edu/sites/default/files/newsroom/0038_nz_panda_0823_c_2014_david_galen.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #76 from https://static01.nyt.com/images/2020/08/16/reader-center/14-panda-baby/14-panda-baby-videoSixteenByNineJumbo1600.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://static.independent.co.uk/s3fs-public/thumbnails/image/2019/01/31/14/panda-bamboo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #78 from https://animals.sandiegozoo.org/sites/default/files/2016-09/T11_0235_033_3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #79 from https://cdn.mos.cms.futurecdn.net/3n8tRry6fYg7sNyhFDPQwR-1200-80.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://i.pinimg.com/originals/2b/3c/97/2b3c978a03a3ee75e829b85592d32242.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #81 from https://i.natgeofe.com/k/75ac774d-e6c7-44fa-b787-d0e20742f797/giant-panda-eating_4x3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #82 from https://nationalzoo.si.edu/sites/default/files/newsroom/20210821-195sb-teaser.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #83 from https://wwfes.awsassets.panda.org/img/panda_gigante_2_98522.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #84 from https://u4d2z7k9.rocketcdn.me/wp-content/uploads/2022/03/1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #85 from https://cdn.pixabay.com/photo/2015/03/04/18/02/panda-659186_1280.png
# [%] File Downloaded !
#
# [%] Downloading Image #86 from https://www.boredpanda.com/blog/wp-content/uploads/2022/12/facts-about-pandas-cover_800.png
# [%] File Downloaded !
#
# [%] Downloading Image #87 from http://dailywildlifephoto-staging.s3.amazonaws.com/system/uploads/photo/image/1258/sized_Panda_Resting.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #88 from https://a-z-animals.com/media/2020/12/giant-panda-sleeping-1000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #89 from https://facts.net/wp-content/uploads/2020/08/Red-Panda-Facts.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #90 from https://i.ytimg.com/vi/4NJlUribp3c/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #91 from https://www-bibliadabiblia-com-br.dnsimg.com/bimg/2024/11/c261c3a5d90ac0d6410b0599f541ec10-43.png
# [%] File Downloaded !
#
# [%] Downloading Image #92 from https://media.oceanpark.com.hk/files/s3fs-public/op-panda-100days-1920x1000-en.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #93 from https://d6ozfheqtj1tz.cloudfront.net/ChIJEyCa80HPD4gRmTjVQYdC4hw/5c2cd521cb078.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #94 from http://ios.gbetsin.com/img/foreign-admission.jpg
# [!] Issue getting: http://ios.gbetsin.com/img/foreign-admission.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #94 from https://static.mytuner.mobi/media/podcasts/010/panda1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #95 from https://art.hudistore.com/wp-content/uploads/2024/11/Leonardo_Phoenix_This_image_shows_a_large_cozy_pink_pandashape_1-jpg.webp
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #96 from http://2.bp.blogspot.com/-3UXfWJ-5-DI/UPBn4xiUkFI/AAAAAAAAGSM/8_fwaqtbZhI/s1600/panda_iStock_000018884983Medium.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #97 from https://cdn.pixabay.com/photo/2023/11/07/15/31/red-panda-8372704_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://s-i.huffpost.com/gen/1541615/images/o-PANDA-facebook.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #99 from https://facts.net/wp-content/uploads/2020/07/Panda-Facts.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #100 from https://png.pngtree.com/png-clipart/20230405/original/pngtree-happy-panda-vector-illustration-png-image_9026596.png
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 100 images.
# [%] Downloading Images to /content/dataset/duck
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/7/74/White_domesticated_duck,_stretching.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.treehugger.com/thmb/g-DBaMaN9i_byti5UFTsmDLFdYk=/4560x3924/filters:fill(auto,1)/duckling-close-up-500315849-572917c93df78ced1f0b99ec.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://passnownow.com/wp-content/uploads/2015/06/duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://upload.wikimedia.org/wikipedia/commons/5/5c/Pair_of_white_domesticated_ducks.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.whateats.com/wp-content/uploads/2010/04/duck-jaroslav-novak.jpt_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://upload.wikimedia.org/wikipedia/commons/2/28/Duck_wings_outstretched.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://www.alifeofheritage.com/wp-content/uploads/2018/05/Duck-Mallard-Ducks-1024x674.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://wallpapercave.com/wp/5PaCHum.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://www.thehappychickencoop.com/wp-content/uploads/2021/04/call-duck-breed.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://thumbs.dreamstime.com/z/pristine-white-duck-785824.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://cdn.britannica.com/92/100692-050-5B69B59B/Mallard.jpg
# [Error]Invalid image, not saving https://cdn.britannica.com/92/100692-050-5B69B59B/Mallard.jpg
#
# [!] Issue getting: https://cdn.britannica.com/92/100692-050-5B69B59B/Mallard.jpg
# [!] Error:: Invalid image, not saving https://cdn.britannica.com/92/100692-050-5B69B59B/Mallard.jpg
#
# [%] Downloading Image #11 from https://media.4-paws.org/a/f/4/7/af47ae6aa55812faa4d7fd857a6e283a8c8226bc/VIER PFOTEN_2019-07-18_013-2890x2000-1920x1329.jpg
# [!] Issue getting: https://media.4-paws.org/a/f/4/7/af47ae6aa55812faa4d7fd857a6e283a8c8226bc/VIER PFOTEN_2019-07-18_013-2890x2000-1920x1329.jpg
# [!] Error:: URL can't contain control characters. '/a/f/4/7/af47ae6aa55812faa4d7fd857a6e283a8c8226bc/VIER PFOTEN_2019-07-18_013-2890x2000-1920x1329.jpg' (found at least ' ')
# [%] Downloading Image #11 from http://upload.wikimedia.org/wikipedia/commons/8/86/Wood.duck.arp.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://thefrugalchicken.com/wp-content/uploads/2023/04/Cute-duck-up-close-min-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://1.bp.blogspot.com/-g4yf6Xl1lV8/TWG3A-K-HYI/AAAAAAAAA8I/3QxpPFy_KXE/s1600/Mandarin.duck.arp.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://www.marylandzoo.org/wp-content/uploads/2017/11/woodduck2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.pianz.org.nz/wp-content/uploads/2016/03/pekin-duck.jpg
# [!] Issue getting: https://www.pianz.org.nz/wp-content/uploads/2016/03/pekin-duck.jpg
# [!] Error:: HTTP Error 520:
# [%] Downloading Image #15 from https://i.natgeofe.com/n/abe018d7-83a0-42e2-84c0-077af93801ce/mallard-duck_thumb_2x3.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://environment.co/wp-content/uploads/sites/4/2023/02/jeffrey-hamilton-ArLOiOoR5L0-unsplash-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from http://whitestonefarm.com.au/wp-content/uploads/2012/05/ducks.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://www.westfield.ma.edu/PersonalPages/draker/edcom/final/webprojects/sp11/farmanimals/farm-duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://thefrugalchicken.com/wp-content/uploads/2022/10/Call-Ducks-min.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://images.saymedia-content.com/.image/t_share/MTk3MTQxNDI5MDMyNTkyNDY3/top-10-duck-snacks.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://i.pinimg.com/originals/06/af/8e/06af8e9409378c13ecc140b78ae4de9b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://www.gma.vic.gov.au/__data/assets/image/0005/499811/Pacific-Black-Duck-monomorphic.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://opticsmag.com/wp-content/uploads/2022/11/Mottled-Duck-vs-Mallard-vs-Black-Duck-side-by-side.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://everipedia-storage.s3-accelerate.amazonaws.com/ProfilePics/252962__48016.jpeg
# [Error]Invalid image, not saving https://everipedia-storage.s3-accelerate.amazonaws.com/ProfilePics/252962__48016.jpeg
#
# [!] Issue getting: https://everipedia-storage.s3-accelerate.amazonaws.com/ProfilePics/252962__48016.jpeg
# [!] Error:: Invalid image, not saving https://everipedia-storage.s3-accelerate.amazonaws.com/ProfilePics/252962__48016.jpeg
#
# [%] Downloading Image #24 from http://www.tonyanthony.co.uk/wp-content/uploads/2014/08/Duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from http://2.bp.blogspot.com/-bI-KzVeh-kg/TbRH9Ay_I_I/AAAAAAAAAAM/rFgicls1xKE/s1600/whiteduck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://1.bp.blogspot.com/-O-lES1gSRoI/Tdn8eC9VmtI/AAAAAAAABNo/3_U0k1N5G1c/s1600/duck2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://www.poultryhub.org/content/uploads/2012/06/Ducks12.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://www.animalspot.net/wp-content/uploads/2019/10/Types-of-Ducks.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://hgtvhome.sndimg.com/content/dam/images/grdn/fullset/2014/4/24/0/Original_orig-steele-duck-housing-2.jpg.rend.hgtvcom.1280.1280.suffix/1452647550580.jpeg
# [!] Issue getting: https://hgtvhome.sndimg.com/content/dam/images/grdn/fullset/2014/4/24/0/Original_orig-steele-duck-housing-2.jpg.rend.hgtvcom.1280.1280.suffix/1452647550580.jpeg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #29 from http://upload.wikimedia.org/wikipedia/commons/3/30/Flying_mallard_duck_-_female.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://rspca.sfo2.cdn.digitaloceanspaces.com/public/Uploads/responsible-sourcing/duck__FocusFillWzc1MSw4ODAsIngiLDM5NF0.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #31 from https://i.natgeofe.com/k/327b01e8-be2e-4694-9ae9-ae7837bd8aea/mallard-male-swimming_16x9.jpg?w=1200
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://c2.peakpx.com/wallpaper/474/783/757/duck-white-ducks-animal-water-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://www.warrenphotographic.co.uk/photography/bigs/09567-White-duck-white-background.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://4.bp.blogspot.com/-c-ZxM5B0N4w/WpmKatXHobI/AAAAAAAAA90/AlCyGtAf1kwyhjafIiVq43e9QN4OHF7dwCLcBGAs/s1600/Pair%2Bon%2Bwater%2BMP.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from http://3.bp.blogspot.com/-2EqR3JYGV6Y/T__iWIzXXsI/AAAAAAAAB8Y/ZajppozULfA/s1600/little-yellow-duck-swimming-hd-duck-wallpaper-animal.jpg
# [!] Issue getting: http://3.bp.blogspot.com/-2EqR3JYGV6Y/T__iWIzXXsI/AAAAAAAAB8Y/ZajppozULfA/s1600/little-yellow-duck-swimming-hd-duck-wallpaper-animal.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #35 from https://www.wallpapersshare.com/img/big/beautiful-brown-duck-4k.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #36 from https://2.bp.blogspot.com/-BBEQgfC3Fd4/UmJXSeTI9YI/AAAAAAAAAaA/QYoX9K-qElY/s1600/mallard+duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://www.omlet.us/images/originals/call-duck-ducks-gardening-call-duck--ethel-67432f81_385106d3.jpg
# [Error]Invalid image, not saving https://www.omlet.us/images/originals/call-duck-ducks-gardening-call-duck--ethel-67432f81_385106d3.jpg
#
# [!] Issue getting: https://www.omlet.us/images/originals/call-duck-ducks-gardening-call-duck--ethel-67432f81_385106d3.jpg
# [!] Error:: Invalid image, not saving https://www.omlet.us/images/originals/call-duck-ducks-gardening-call-duck--ethel-67432f81_385106d3.jpg
#
# [%] Downloading Image #37 from https://eskipaper.com/images/duck-water-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://freepngimg.com/thumb/duck/21-white-duck-png-image.png
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://www.learnaboutnature.com/wp-content/uploads/ducks.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from http://upload.wikimedia.org/wikipedia/commons/9/97/Ducks_in_plymouth%2C_massachusetts.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://www.ruralsprout.com/wp-content/uploads/2021/07/duck-breeds-cayuga.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from http://hgtvhome.sndimg.com/content/dam/images/grdn/fullset/2013/1/25/0/Original_pekin-duck.jpg.rend.hgtvcom.1280.853.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://cdn.wallpapersafari.com/72/43/kxTJ8r.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from https://www.publicdomainpictures.net/pictures/80000/nahled/duck-on-white-background-1393007587oFD.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://c1.peakpx.com/wallpaper/242/657/284/mallard-duck-bird-feathers-nature-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://c2.peakpx.com/wallpaper/875/175/598/duck-mallard-coy-fish-pond-birds-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from http://hgtvhome.sndimg.com/content/dam/images/grdn/fullset/2013/3/25/0/Original_saxony-ducks.jpg.rend.hgtvcom.1280.960.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #48 from https://critter.science/wp-content/uploads/2022/06/bd1a-1180x520.jpg
# [!] Issue getting: https://critter.science/wp-content/uploads/2022/06/bd1a-1180x520.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #48 from https://birdsflight.com/wp-content/uploads/2012/04/female-mallard.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://keyassets.timeincuk.net/inspirewp/live/wp-content/uploads/sites/3/2016/03/Best-duck-breeds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://3.bp.blogspot.com/-x7QhwP9wbm0/VfntTMKRXBI/AAAAAAAAC0U/SAH2VpcBkp8/s1600/092A2757.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #51 from http://gabebalazsphoto.com/misc_photos/Mallard Duck flying.jpg
# [!] Issue getting: http://gabebalazsphoto.com/misc_photos/Mallard Duck flying.jpg
# [!] Error:: URL can't contain control characters. '/misc_photos/Mallard Duck flying.jpg' (found at least ' ')
# [%] Downloading Image #51 from https://www.ndow.org/wp-content/uploads/2021/10/aythya_collaris.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #52 from https://owendeutsch.com/wp-content/uploads/2019/05/Yellow-billed-Duck-10RCS.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://www.warrenphotographic.co.uk/photography/bigs/05168-Mallard-duck-drake-and-duckling-white-background.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from http://justbirding.com/wp-content/uploads/2018/11/mandarin-duck-Aix-galericulata.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://upload.wikimedia.org/wikipedia/commons/3/30/Flying_mallard_duck_-_female.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://opticsmag.com/wp-content/uploads/2022/11/Mottled-Duck-vs-Mallard-vs-Black-Duck-side-by-side-1024x586.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from http://www.naturephoto-cz.com/fullsize/birds/tufted-duck-155005.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 3
#
# [%] Indexed 35 Images on Page 3.
#
# ===============================================
#
# [%] Downloading Image #58 from https://i2.wp.com/passnownow.com/wp-content/uploads/2015/06/duck.jpg?fit=2000%2C1339&amp;ssl=1
# [!] Issue getting: https://i2.wp.com/passnownow.com/wp-content/uploads/2015/06/duck.jpg?fit=2000%2C1339&amp;ssl=1
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #58 from https://www.thoughtco.com/thmb/g-DBaMaN9i_byti5UFTsmDLFdYk=/4560x3924/filters:fill(auto,1)/duckling-close-up-500315849-572917c93df78ced1f0b99ec.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #59 from http://upload.wikimedia.org/wikipedia/commons/b/b7/Musk_Duck.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #60 from https://livestockconservancy.org/wp-content/uploads/2022/08/Cayuga-Ducks-scaled.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #61 from https://freepngimg.com/thumb/duck/6-little-duck-png-image.png
# [%] File Downloaded !
#
# [%] Downloading Image #62 from https://cdn.download.ams.birds.cornell.edu/api/v1/asset/110122741/1800
# [%] File Downloaded !
#
# [%] Downloading Image #63 from https://i.pinimg.com/originals/34/eb/71/34eb71be00f31aa4395610856d9a7d2f.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #64 from https://www.collinsdictionary.com/images/full/duck_170690246.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #65 from https://images.pexels.com/photos/724372/pexels-photo-724372.jpeg?auto=compress&amp;cs=tinysrgb&amp;w=1200
# [%] File Downloaded !
#
# [%] Downloading Image #66 from https://easydrawingart.com/wp-content/uploads/2019/08/How-to-draw-a-duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #67 from https://hongkongfp.com/wp-content/uploads/2023/06/20230610_164855-Copy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from https://drawinghowtos.com/wp-content/uploads/2019/04/duck-colored.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from https://i.redd.it/hf5bm0o920r31.jpg
# [!] Issue getting: https://i.redd.it/hf5bm0o920r31.jpg
# [!] Error:: HTTP Error 403: Blocked
# [%] Downloading Image #69 from https://www.clipartkey.com/mpngs/m/133-1339899_transparent-ducks-clipart-yellow-duck-cartoon.png
# [%] File Downloaded !
#
# [%] Downloading Image #70 from https://clipground.com/images/clipart-duck-4.png
# [%] File Downloaded !
#
# [%] Downloading Image #71 from http://english.news.cn/20230609/4850907cb3744047abf6561a4fb32594/192f70aee1b04babbe2a1f4b5c268341.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #72 from https://cookmorphosis.com/wp-content/uploads/2022/09/feature-homemade-cantonese-roasted-duck-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://images.pexels.com/photos/2373360/pexels-photo-2373360.jpeg?auto=compress&amp;cs=tinysrgb&amp;w=1600
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://eshop.oxfam.org.hk/wp-content/uploads/2021/10/24_Duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #75 from https://cdn.pixabay.com/photo/2023/01/12/05/32/duck-7713310_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #76 from https://www.slashfilm.com/img/gallery/how-donald-duck-once-sparked-a-logistical-argument-with-disney-about-life-preservers/l-intro-1674674557.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://www.foodandwine.com/thmb/da3kQ5oyv9lEU0lyaWlCyBI11Sk=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/peking-duck-FT-RECIPE0821-401d953c2b64446dbd8ddbfdb57a1f68.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 4
#
# [%] Indexed 35 Images on Page 4.
#
# ===============================================
#
# [%] Downloading Image #78 from https://3.bp.blogspot.com/--XA3iMvaJLY/Tw_GykPs-eI/AAAAAAAAEgU/EmFKS7Cz5xQ/s1600/Duck-04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #79 from https://www.gordonramsay.com/assets/Recipes/_resampled/CroppedFocusedImage108081050-50-40-DuckChinese-Pankaes-653.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://pbs.twimg.com/media/F00ap37aEAAeeLD.jpg:large
# [%] File Downloaded !
#
# [%] Downloading Image #81 from http://www.christopherpollard.com/wp-content/uploads/2013/02/Pollard_Greyduck_02212013.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 5
#
# [%] Indexed 35 Images on Page 5.
#
# ===============================================
#
# [%] Downloading Image #82 from http://www.publicdomainpictures.net/pictures/40000/velka/duck-1363951979rTe.jpg
# [Error]Invalid image, not saving http://www.publicdomainpictures.net/pictures/40000/velka/duck-1363951979rTe.jpg
#
# [!] Issue getting: http://www.publicdomainpictures.net/pictures/40000/velka/duck-1363951979rTe.jpg
# [!] Error:: Invalid image, not saving http://www.publicdomainpictures.net/pictures/40000/velka/duck-1363951979rTe.jpg
#
# [%] Downloading Image #82 from https://duckheroes.weebly.com/uploads/8/3/0/8/83089084/image0-7_orig.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #83 from https://cdn.pixabay.com/photo/2023/12/21/18/01/duck-8462289_1280.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 6
#
# [%] Indexed 35 Images on Page 6.
#
# ===============================================
#
#
#
# [!!]Indexing page: 7
#
# [%] Indexed 35 Images on Page 7.
#
# ===============================================
#
#
#
# [!!]Indexing page: 8
#
# [%] Indexed 35 Images on Page 8.
#
# ===============================================
#
# [%] Downloading Image #84 from http://www.publicdomainpictures.net/pictures/60000/velka/duck-13791602735wo.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 9
#
# [%] Indexed 35 Images on Page 9.
#
# ===============================================
#
# [%] Downloading Image #85 from https://www.thoughtco.com/thmb/WbeDhF7XzPtwHC2acQC44ESQ5j8=/2430x0/filters:no_upscale():max_bytes(150000):strip_icc()/duckling-close-up-500315849-572917c93df78ced1f0b99ec.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #86 from https://opticsmag.com/wp-content/uploads/2022/11/Mottled-Duck-vs-Mallard-vs-Black-Duck.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #87 from https://cdn.pixabay.com/photo/2024/11/11/15/46/black-headed-duck-9190336_1280.jpg
# [!] Issue getting: https://cdn.pixabay.com/photo/2024/11/11/15/46/black-headed-duck-9190336_1280.jpg
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 10
#
# [%] Indexed 35 Images on Page 10.
#
# ===============================================
#
# [%] Downloading Image #87 from https://www.treehugger.com/thmb/-2rSLwK3cjwtNHr5M9ly84XffhU=/774x0/filters:no_upscale():max_bytes(150000):strip_icc()/duckling-close-up-500315849-572917c93df78ced1f0b99ec.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #88 from http://www.keweenawreport.com/wp-content/uploads/2015/03/Male_mallard_duck_2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #89 from http://pngimg.com/uploads/duck/duck_PNG4999.png
# [%] File Downloaded !
#
# [%] Downloading Image #90 from https://images.pexels.com/videos/1200910/free-video-1200910.jpg?auto=compress&amp;cs=tinysrgb&amp;w=1600
# [%] File Downloaded !
#
# [%] Downloading Image #91 from https://cdn.pixabay.com/photo/2017/01/14/02/22/duck-1978680_640.png
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 11
#
# [%] Indexed 35 Images on Page 11.
#
# ===============================================
#
# [%] Downloading Image #92 from https://i.pinimg.com/originals/95/ad/b6/95adb6963f9109c045cb990e4f0a6267.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 12
#
# [%] Indexed 35 Images on Page 12.
#
# ===============================================
#
# [%] Downloading Image #93 from https://cdn.pixabay.com/photo/2023/03/14/08/34/duck-7851828_640.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #94 from https://www.plasmaspider.com/images/DuckHunterF3.png
# [%] File Downloaded !
#
# [%] Downloading Image #95 from https://i5.walmartimages.com/seo/Duck-Smoking-Cigarette-Meme-T-Shirt_19f16fe0-693d-4434-8f7a-4587bf84fd51.6e41b2ba64b40435f2196aebe020a4a2.jpeg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 13
#
# [%] Indexed 35 Images on Page 13.
#
# ===============================================
#
# [%] Downloading Image #96 from https://cdn.pixabay.com/photo/2023/11/10/20/32/duck-8380065_1280.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 14
#
# [%] Indexed 35 Images on Page 14.
#
# ===============================================
#
# [%] Downloading Image #97 from https://www.thoughtco.com/thmb/b-Y181htI0QLOrasaUJNtUmIMgQ=/4560x0/filters:no_upscale():max_bytes(150000):strip_icc()/duckling-close-up-500315849-572917c93df78ced1f0b99ec.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 15
#
# [%] Indexed 35 Images on Page 15.
#
# ===============================================
#
# [%] Downloading Image #98 from https://c0.klipartz.com/pngpicture/782/676/gratis-png-daisy-duck-mickey-mouse-donald-duck-minnie-mouse-la-compania-walt-disney-mickey-mouse-thumbnail.png
# [%] File Downloaded !
#
# [%] Downloading Image #99 from https://i5.walmartimages.com/seo/Duck-Smoking-Cigarette-Meme-T-Shirt_19f16fe0-693d-4434-8f7a-4587bf84fd51.6e41b2ba64b40435f2196aebe020a4a2.jpeg?odnHeight=640&amp;odnWidth=640&amp;odnBg=FFFFFF
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 16
#
# [%] Indexed 35 Images on Page 16.
#
# ===============================================
#
#
#
# [!!]Indexing page: 17
#
# [%] Indexed 35 Images on Page 17.
#
# ===============================================
#
# [%] Downloading Image #100 from https://duckheroes.weebly.com/uploads/8/3/0/8/83089084/image0-5_orig.jpeg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 100 images.
# Images downloaded successfully!

# %%
import shutil

# Define the source and destination paths
source_folder = '/content/dataset'
destination_folder = '/content/drive/MyDrive/MLDataset'

# Copy the folder to Google Drive
shutil.copytree(source_folder, destination_folder)
# Out:
# '/content/drive/MyDrive/MLDataset'

# %%
import os
folder_path = '/content/drive/MyDrive/MLDataset/panda'  # Replace with your folder path
file_count = len([file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))])

print(f"Number of files in '{folder_path}':", file_count)
# Out:
# Number of files in '/content/drive/MyDrive/MLDataset/panda': 100

# %%
import os
folder_path = '/content/dataset/duck'  # Replace with your folder path
file_count = len([file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))])

print(f"Number of files in '{folder_path}':", file_count)
# Out:
# Number of files in '/content/dataset/duck': 100

# %%
import torch
import torchvision
import torch.optim as optim
from torchvision import transforms
from PIL import Image
from torch.utils.data import DataLoader, random_split,Dataset
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from tqdm import tqdm

# %%
class ImageLabelDataset(Dataset):
  def __init__(self, data_dir, transform=None):
    self.data_dir = data_dir
    self.image_paths = [os.path.join(data_dir, f) for f in os.listdir(data_dir) if os.path.isfile(os.path.join(data_dir, f))]
    self.transform = transform

  def __len__(self):
    return len(self.image_paths)

  def __getitem__(self, idx):
    image_path = self.image_paths[idx]
    # Load image as RGB (mode='RGB')
    image = Image.open(image_path).convert('RGB')
    # Assuming your labels are encoded in the filenames (modify as needed)
    label = os.path.splitext(os.path.basename(image_path))[0].split("_")[0]
    # Convert label to integer if needed (modify as needed)
    #print("LABEL: ",label)
    if label == 'panda':
        label = [0,1]
    else:
        label = [1,0]
    if self.transform:
      image = self.transform(image)
    return image, label

# %%
import os
import shutil

# Define the paths
panda_folder = '/content/drive/My Drive/MLDataset/panda'
duck_folder = '/content/drive/My Drive/MLDataset/duck'
combined_folder = '/content/drive/My Drive/MLDataset/combine'

# Create the combined folder if it doesn't exist
os.makedirs(combined_folder, exist_ok=True)

# Copy and rename images from panda folder
for filename in os.listdir(panda_folder):
    source_path = os.path.join(panda_folder, filename)
    destination_path = os.path.join(combined_folder, f"panda_{filename}")
    shutil.copy(source_path, destination_path)

# Copy and rename images from duck folder
for filename in os.listdir(duck_folder):
    source_path = os.path.join(duck_folder, filename)
    destination_path = os.path.join(combined_folder, f"duck_{filename}")
    shutil.copy(source_path, destination_path)

# Verify the count
print("Number of files in '/content/drive/My Drive/MLDataset/combine':", len(os.listdir(combined_folder)))
# Out:
# Number of files in '/content/drive/My Drive/MLDataset/combine': 200

# %%
data_dir = '/content/drive/My Drive/MLDataset/combine'
data_transforms = transforms.Compose([
  transforms.Resize((200,200)),  # Resize images to 256x256
  transforms.ToTensor(),
  transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
dataset = ImageLabelDataset(data_dir,data_transforms)

# %%
import os
folder_path = '/content/drive/MyDrive/MLDataset/combine'  # Replace with your folder path
file_count = len([file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))])

print(f"Number of files in '{folder_path}':", file_count)
# Out:
# Number of files in '/content/drive/MyDrive/MLDataset/combine': 200

# %%
print(dataset[0][0].shape)
# Out:
# torch.Size([3, 200, 200])

# %%
test_size = 0.2
train_size = int(len(dataset) * (1 - test_size))
train_dataset, test_dataset = random_split(dataset, [train_size, len(dataset) - train_size])

# Create training and testing loaders
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# Augementing

# %%
data_transforms_ = transforms.Compose([

  transforms.ToTensor(),
  transforms.RandomHorizontalFlip(p=1),                 #Flips the image horizontally (mirrored along the vertical axis) with p=1, all images will always be flipped horizontally
  transforms.RandomVerticalFlip(p=1),
  transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5),
  transforms.RandomRotation(degrees=(-90,90))
])

# %%
src_dir="/content/drive/MyDrive/MLDataset/combine/"
dest_dir="/content/drive/MyDrive/MLDataset/combine_augmented/"

# %%
import os
from PIL import Image
from torchvision import transforms

src_dir="/content/drive/MyDrive/MLDataset/combine/"
dest_dir="/content/drive/MyDrive/MLDataset/combine_augmented/"

if not os.path.exists(dest_dir):
    os.mkdir(dest_dir)

# Get a list of files from the source directory
onlyfiles = [f for f in os.listdir(src_dir) if os.path.isfile(os.path.join(src_dir, f))]


# data_transforms_ = transforms.Compose([
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomRotation(30),
#     transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
#     transforms.ToTensor()
# ])

# Process each file in the source directory
for file in onlyfiles:
    # Open the image
    image = Image.open(os.path.join(src_dir, file)).convert('RGB')

    # Perform the transformation
    image_aug = data_transforms_(image)
    image_aug = transforms.ToPILImage()(image_aug)

    # Split the filename to generate new names for augmented images
    label = os.path.splitext(file)[0].split("_Image_")
    # Check if the label has at least two parts to avoid index error
    if len(label) < 2:
        continue

    # Save the original image to the destination directory
    image.save(os.path.join(dest_dir, f"{label[0]}_{label[1]}.jpg"))
    # Save the augmented image to the destination directory
    image_aug.save(os.path.join(dest_dir, f"{label[0]}_a_{label[1]}.jpg"))

print("Images have been successfully processed and saved.")
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Images have been successfully processed and saved.

# %%
data_transforms = transforms.Compose([
  transforms.Resize((200,200)),  # Resize images to 256x256
  transforms.ToTensor(),
  transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
import os
folder_path = '/content/drive/MyDrive/MLDataset/combine_augmented/'  # Replace with your folder path
file_count = len([file for file in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, file))])

print(f"Number of files in '{folder_path}':", file_count)
# Out:
# Number of files in '/content/drive/MyDrive/MLDataset/combine_augmented/': 400

# %%
dataset_ = ImageLabelDataset(dest_dir,data_transforms)

test_size = 0.2
train_size = int(len(dataset_) * (1 - test_size))
train_dataset_, test_dataset_ = random_split(dataset_, [train_size, len(dataset_) - train_size])

# Create training and testing loaders
train_loader_ = torch.utils.data.DataLoader(train_dataset_, batch_size=32, shuffle=True)
test_loader_ = torch.utils.data.DataLoader(test_dataset_, batch_size=32, shuffle=False)

# %%
len(test_loader_.dataset)
# Out:
# 80
